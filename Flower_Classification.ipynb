# %%
import torch
torch.__version__
# Out:
# '1.8.1+cu101'

# %%
import fastai
fastai.__version__
# Out:
# '2.3.1'

# %%
pip install fastai --upgrade
# Out:
# Requirement already up-to-date: fastai in /usr/local/lib/python3.7/dist-packages (2.3.1)
# ...

# %%
from fastai.vision.all import *

# %%
df=!unzip /content/flowers.zip -d path_to_directory

# %%
path=Path("/content/path_to_directory/flowers")

# %%
data=ImageDataLoaders.from_folder(path, valid_pct=0.2, item_tfms=Resize(224))

# %%
data.show_batch(figsize=(15,10))

# %%
model=cnn_learner(data,resnet101, metrics=[error_rate, accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...

# %%
model.lr_find()
# Out:
# SuggestedLRs(lr_min=0.006918309628963471, lr_steep=0.0012022644514217973)

# %%
model.fine_tune(2, 0.01)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.611571</td>
#       <td>0.374708</td>
#       <td>0.112269</td>
#       <td>0.887731</td>
#       <td>00:56</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.462606</td>
#       <td>0.666757</td>
#       <td>0.171296</td>
#       <td>0.828704</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.276073</td>
# ...

# %%
model.show_results(figsize=(15,10))

# %%
interp=Interpretation.from_learner(model)
interp.plot_top_losses(9,figsize=(20,10))

# %%
model.save('final_model')
# Out:
# Path('/content/path_to_directory/flowers/models/final_model.pth')
